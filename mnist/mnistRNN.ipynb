# %%
import tensorflow as tf
from tensorflow.contrib import rnn
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/home/yanbin/data/MNIST_data/",one_hot=True)
# Out:
# Extracting /home/yanbin/data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting /home/yanbin/data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting /home/yanbin/data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /home/yanbin/data/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 28 # MNIST data input (img shape: 28*28)
n_steps = 28 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)
    
    # Unstack to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, n_steps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

pred = RNN(x, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: test_data, y: test_label})
# Out:
# Iter 1280, Minibatch Loss= 1.920184, Training Accuracy= 0.31250
# Iter 2560, Minibatch Loss= 1.638944, Training Accuracy= 0.43750
# Iter 3840, Minibatch Loss= 1.401844, Training Accuracy= 0.51562
# Iter 5120, Minibatch Loss= 1.154263, Training Accuracy= 0.60938
# Iter 6400, Minibatch Loss= 0.949795, Training Accuracy= 0.65625
# Iter 7680, Minibatch Loss= 0.756653, Training Accuracy= 0.76562
# Iter 8960, Minibatch Loss= 0.593605, Training Accuracy= 0.79688
# Iter 10240, Minibatch Loss= 0.476918, Training Accuracy= 0.84375
# Iter 11520, Minibatch Loss= 0.541496, Training Accuracy= 0.82812
# Iter 12800, Minibatch Loss= 0.504022, Training Accuracy= 0.82812
# Iter 14080, Minibatch Loss= 0.470071, Training Accuracy= 0.85938
# Iter 15360, Minibatch Loss= 0.271661, Training Accuracy= 0.91406
# Iter 16640, Minibatch Loss= 0.342396, Training Accuracy= 0.88281
# Iter 17920, Minibatch Loss= 0.424778, Training Accuracy= 0.86719
# Iter 19200, Minibatch Loss= 0.410023, Training Accuracy= 0.89844
# Iter 20480, Minibatch Loss= 0.304686, Training Accuracy= 0.89844
# Iter 21760, Minibatch Loss= 0.273564, Training Accuracy= 0.92188
# Iter 23040, Minibatch Loss= 0.390835, Training Accuracy= 0.86719
# Iter 24320, Minibatch Loss= 0.206551, Training Accuracy= 0.93750
# Iter 25600, Minibatch Loss= 0.306641, Training Accuracy= 0.92969
# Iter 26880, Minibatch Loss= 0.284594, Training Accuracy= 0.87500
# Iter 28160, Minibatch Loss= 0.258955, Training Accuracy= 0.91406
# Iter 29440, Minibatch Loss= 0.183855, Training Accuracy= 0.94531
# Iter 30720, Minibatch Loss= 0.310082, Training Accuracy= 0.91406
# Iter 32000, Minibatch Loss= 0.203760, Training Accuracy= 0.93750
# Iter 33280, Minibatch Loss= 0.240509, Training Accuracy= 0.91406
# Iter 34560, Minibatch Loss= 0.180160, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 0.155140, Training Accuracy= 0.95312
# Iter 37120, Minibatch Loss= 0.195120, Training Accuracy= 0.92969
# Iter 38400, Minibatch Loss= 0.415138, Training Accuracy= 0.86719
# Iter 39680, Minibatch Loss= 0.170398, Training Accuracy= 0.93750
# Iter 40960, Minibatch Loss= 0.110132, Training Accuracy= 0.94531
# Iter 42240, Minibatch Loss= 0.127425, Training Accuracy= 0.95312
# Iter 43520, Minibatch Loss= 0.175280, Training Accuracy= 0.93750
# Iter 44800, Minibatch Loss= 0.153241, Training Accuracy= 0.95312
# Iter 46080, Minibatch Loss= 0.184520, Training Accuracy= 0.92188
# Iter 47360, Minibatch Loss= 0.155746, Training Accuracy= 0.92969
# Iter 48640, Minibatch Loss= 0.174951, Training Accuracy= 0.93750
# Iter 49920, Minibatch Loss= 0.160016, Training Accuracy= 0.94531
# Iter 51200, Minibatch Loss= 0.211434, Training Accuracy= 0.92969
# Iter 52480, Minibatch Loss= 0.207982, Training Accuracy= 0.92188
# Iter 53760, Minibatch Loss= 0.174133, Training Accuracy= 0.96094
# Iter 55040, Minibatch Loss= 0.293924, Training Accuracy= 0.90625
# Iter 56320, Minibatch Loss= 0.133710, Training Accuracy= 0.96094
# Iter 57600, Minibatch Loss= 0.151423, Training Accuracy= 0.94531
# Iter 58880, Minibatch Loss= 0.097777, Training Accuracy= 0.98438
# Iter 60160, Minibatch Loss= 0.063915, Training Accuracy= 0.97656
# Iter 61440, Minibatch Loss= 0.088052, Training Accuracy= 0.97656
# Iter 62720, Minibatch Loss= 0.208094, Training Accuracy= 0.92969
# Iter 64000, Minibatch Loss= 0.176381, Training Accuracy= 0.95312
# Iter 65280, Minibatch Loss= 0.117270, Training Accuracy= 0.96875
# Iter 66560, Minibatch Loss= 0.090213, Training Accuracy= 0.98438
# Iter 67840, Minibatch Loss= 0.138799, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 0.101970, Training Accuracy= 0.96094
# Iter 70400, Minibatch Loss= 0.111280, Training Accuracy= 0.96094
# Iter 71680, Minibatch Loss= 0.243040, Training Accuracy= 0.92969
# Iter 72960, Minibatch Loss= 0.145276, Training Accuracy= 0.92969
# Iter 74240, Minibatch Loss= 0.068691, Training Accuracy= 0.96875
# Iter 75520, Minibatch Loss= 0.097650, Training Accuracy= 0.97656
# Iter 76800, Minibatch Loss= 0.089459, Training Accuracy= 0.96094
# Iter 78080, Minibatch Loss= 0.137736, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 0.101878, Training Accuracy= 0.97656
# Iter 80640, Minibatch Loss= 0.110999, Training Accuracy= 0.97656
# Iter 81920, Minibatch Loss= 0.081149, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 0.064346, Training Accuracy= 0.97656
# Iter 84480, Minibatch Loss= 0.061122, Training Accuracy= 0.97656
# Iter 85760, Minibatch Loss= 0.109376, Training Accuracy= 0.97656
# Iter 87040, Minibatch Loss= 0.112398, Training Accuracy= 0.95312
# Iter 88320, Minibatch Loss= 0.048869, Training Accuracy= 0.98438
# Iter 89600, Minibatch Loss= 0.110224, Training Accuracy= 0.97656
# Iter 90880, Minibatch Loss= 0.082181, Training Accuracy= 0.96094
# Iter 92160, Minibatch Loss= 0.164482, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 0.090230, Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 0.061842, Training Accuracy= 0.97656
# Iter 96000, Minibatch Loss= 0.148890, Training Accuracy= 0.93750
# Iter 97280, Minibatch Loss= 0.147996, Training Accuracy= 0.94531
# Iter 98560, Minibatch Loss= 0.044240, Training Accuracy= 0.99219
# Iter 99840, Minibatch Loss= 0.154003, Training Accuracy= 0.95312
# Optimization Finished!
# Testing Accuracy: 0.984375
