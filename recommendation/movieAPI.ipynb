# %%
#/usr/bin/env python
#-*- coding:utf-8-*-
import requests
import json
import os
import urllib
import os.path
import pandas as pd
class MovieDB(object):
    def __init__(self,url = 'http://api.themoviedb.org/3',
                    headers = {'Accept':'application/json'},
                    payload = {'api_key':'e0ec617d1ba0c2c3adb4f43df47f9ab4'}):
        self.url = url
        self.headers = headers
        self.payload = payload
        
    def getImageBasePath(self,size='w185'):
        response = requests.get(self.url+'/configuration',params=self.payload,headers=self.headers)
        response = json.loads(response.text)
        base_url = response['images']['base_url']+'w185'
        return base_url
    
    def get_poster(self,imdb):
        #query themovie.org API for movie poster path.
        base_url = self.getImageBasePath()
        file_path = ''
        imdb_id = 'tt0{0}'.format(imdb)
        movie_url = self.url+'/movie/{:}/images'.format(imdb_id)
        response = requests.get(movie_url,params=self.payload,headers=self.headers)
        try:
            file_path = json.loads(response.text)['posters'][0]['file_path']
        except:
            print('Failed to get url for imdb: {0}'.format(imdb))
        return base_url+file_path
    
    def getIDs(self,link_f="./Recommend-movies/ml-latest-small/links.csv",download_posters=1000):
        df_id = pd.read_csv(link_f,sep=',')
        idx_to_mv = {}
        for row in df_id.itertuples():
            idx_to_mv[row[1]-1] = row[2]
        mvs = [0]*len(idx_to_mv.keys())
        for i in range(len(mvs)):
            if i in idx_to_mv.keys() and len(str(idx_to_mv[i])) == 6:
                mvs[i] = idx_to_mv[i]
        mvs = list(filter(lambda imdb:imdb!=0,mvs))
#         shuffle_index = range(len(mvs))
#         np.random.shuffle(shuffle_index)
#         mvs = [mvs[i] for i in mvs]
        mvs = mvs[:download_posters]
        return mvs
    
    def down_poster(self,mvs,poster_pt='./poster/'):
        base_url = self.getImageBasePath()
        total_mvs = len(mvs)
        URL = [0]*total_mvs
        URL_IMDB = {'url':[],'imdb':[]}
        i=0
        for m in mvs:
            if(os.path.exists(poster_pt+str(i)+'.jpg')):
                print('Skip downloading exists jpg: {0}.jpg'.format(poster_pt+str(i)))
                i += 1
                continue
            URL[i] = self.get_poster(m)
            if(URL[i] == base_url):
                print('Bad imdb id: {0}'.format(m))
                mvs.remove(m)
                continue
            print('No.{0}: Downloading jpg(imdb {1}) {2}'.format(i,m,URL[i]))
            urllib.urlretrieve(URL[i],poster_pt+str(i)+'.jpg')
            URL_IMDB['url'].append(URL[i])
            URL_IMDB['imdb'].append(m)
            i += 1
        return URL_IMDB
if __name__ == '__main__':        
    movieDb = MovieDB()
    mvs = movieDb.getIDs()
    URL_IMDB = movieDb.down_poster(mvs)
#   url=movieDb.get_poster(mvs[0])
# Out:
# Skip downloading exists jpg: ./poster/0.jpg
# Skip downloading exists jpg: ./poster/1.jpg
# Skip downloading exists jpg: ./poster/2.jpg
# Skip downloading exists jpg: ./poster/3.jpg
# Skip downloading exists jpg: ./poster/4.jpg
# Skip downloading exists jpg: ./poster/5.jpg
# Skip downloading exists jpg: ./poster/6.jpg
# Skip downloading exists jpg: ./poster/7.jpg
# Skip downloading exists jpg: ./poster/8.jpg
# Skip downloading exists jpg: ./poster/9.jpg
# Skip downloading exists jpg: ./poster/10.jpg
# Skip downloading exists jpg: ./poster/11.jpg
# No.288: Downloading jpg(imdb 114614) http://image.tmdb.org/t/p/w185/hTGCzUi3nYdhQTWCk5QgGRTwg3q.jpg
# No.289: Downloading jpg(imdb 114608) http://image.tmdb.org/t/p/w185/8uD5yk0ECebJ59lhvhTBKhUojc.jpg
# No.290: Downloading jpg(imdb 111280) http://image.tmdb.org/t/p/w185/3qR2uy8h6nKalvu6zwBEbtYxpf5.jpg
# No.291: Downloading jpg(imdb 114609) http://image.tmdb.org/t/p/w185/3OrapxFNr12AhRxupQ8Z2jP1D13.jpg
# No.292: Downloading jpg(imdb 111454) http://image.tmdb.org/t/p/w185/vLh2r5QyIooLhmYNYEaSZ4Jxsav.jpg
# No.293: Downloading jpg(imdb 114852) http://image.tmdb.org/t/p/w185/iwmI6kZWPJ9TYC4PJ0fi80TNFx5.jpg
# No.294: Downloading jpg(imdb 114694) http://image.tmdb.org/t/p/w185/lbsuDUaTH9POXWb4Inyck8gZFck.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3fc102bbc420> in <module>()
#      75     movieDb = MovieDB()
#      76     mvs = movieDb.getIDs()
# ---> 77     URL_IMDB = movieDb.down_poster(mvs)
#      78 #   url=movieDb.get_poster(mvs[0])
#
# <ipython-input-6-3fc102bbc420> in down_poster(self, mvs, poster_pt)
#      67                 continue
#      68             print('No.{0}: Downloading jpg(imdb {1}) {2}'.format(i,m,URL[i]))
# ---> 69             urllib.urlretrieve(URL[i],poster_pt+str(i)+'.jpg')
#      70             URL_IMDB['url'].append(URL[i])
#      71             URL_IMDB['imdb'].append(m)
#
# /usr/lib/python2.7/urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
#     100     if _urlopener:
#
# /usr/lib/python2.7/urllib.pyc in retrieve(self, url, filename, reporthook, data)
#     271                     reporthook(blocknum, bs, size)
#     272                 while 1:
# --> 273                     block = fp.read(bs)
#     274                     if block == "":
#     275                         break
#
# /usr/lib/python2.7/socket.pyc in read(self, size)
#     382                 # fragmentation issues on many platforms.
#     383                 try:
# --> 384                     data = self._sock.recv(left)
#     385                 except error, e:
#     386                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
from IPython.display import Image
from IPython.display import display
from IPython.display import HTML
images="<img style='width: 100px; margin: 0px; float: left; border: 1px solid black;' src='%s' />" % url
#print(images)
display(HTML(images))
# Out:
# <img style='width: 100px; margin: 0px; float: left; border: 1px solid black;' src='http://image.tmdb.org/t/p/w185/uMZqKhT4YA6mqo2yczoznv7IDmv.jpg' />

# %%
from IPython.display import Image
from IPython.display import display
from IPython.display import HTML
images = ''
n_display=len(URL_IMDB['url'])
print URL_IMDB['url']
for i in range(n_display):
        images+="<img style='width: 100px; margin: 0px; float: left; border: 1px solid black;' src='%s' />" % URL_IMDB['url'][i]
print(images)
display(HTML(images))
# Out:
# [u'http://image.tmdb.org/t/p/w185/uMZqKhT4YA6mqo2yczoznv7IDmv.jpg', u'http://image.tmdb.org/t/p/w185/vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg']
# <img style='width: 100px; margin: 0px; float: left; border: 1px solid black;' src='http://image.tmdb.org/t/p/w185/uMZqKhT4YA6mqo2yczoznv7IDmv.jpg' /><img style='width: 100px; margin: 0px; float: left; border: 1px solid black;' src='http://image.tmdb.org/t/p/w185/vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg' />
# <img style='width: 100px; margin: 0px; float: left; border: 1px solid black;' src='http://image.tmdb.org/t/p/w185/uMZqKhT4YA6mqo2yczoznv7IDmv.jpg' /><img style='width: 100px; margin: 0px; float: left; border: 1px solid black;' src='http://image.tmdb.org/t/p/w185/vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg' />

# %%
print shuffle_index
# Out:
# [0, 1, 2, 3]
# [2, 3, 0, 1]
